# %%
import pandas as pd

# %%
df = pd.read_csv('/home/ayush/Desktop/DATASET/0031102-231002084531237/occurrence.txt', delimiter='\t')
pd.set_option('display.max_columns', 300)
# movies.head()
# Out:
# /tmp/ipykernel_9331/1216247096.py:1: DtypeWarning: Columns (82,199) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/home/ayush/Desktop/DATASET/0031102-231002084531237/occurrence.txt', delimiter='\t')

# %%
df.head(5)
# Out:
#        gbifID  accessRights  bibliographicCitation  language       license  \
# 0  2028713273           NaN                    NaN       NaN  CC_BY_NC_4_0
# 1  2028931999           NaN                    NaN       NaN  CC_BY_NC_4_0
# 2  2028715905           NaN                    NaN       NaN  CC_BY_NC_4_0
# 3  2028936907           NaN                    NaN       NaN  CC_BY_NC_4_0
# 4  2028715906           NaN                    NaN       NaN  CC_BY_NC_4_0
#
#    modified publisher  references      rightsHolder   type  institutionID  \
# 0       NaN    PlutoF         NaN  Kristjan Adojaan  Event            NaN
# 1       NaN    PlutoF         NaN  Kristjan Adojaan  Event            NaN
# 2       NaN    PlutoF         NaN  Kristjan Adojaan  Event            NaN
# 3       NaN    PlutoF         NaN  Kristjan Adojaan  Event            NaN
# 4       NaN    PlutoF         NaN  Kristjan Adojaan  Event            NaN
#
# ...

# %%
df.isna().count()
# Out:
# gbifID                   885595
# accessRights             885595
# bibliographicCitation    885595
# language                 885595
# license                  885595
#                           ...
# level2Name               885595
# level3Gid                885595
# level3Name               885595
# iucnRedListCategory      885595
# eventType                885595
# Length: 212, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885595 entries, 0 to 885594
# Columns: 212 entries, gbifID to eventType
# dtypes: bool(2), float64(146), int64(19), object(45)
# memory usage: 1.4+ GB

# %%
df.columns
# Out:
# Index(['gbifID', 'accessRights', 'bibliographicCitation', 'language',
#        'license', 'modified', 'publisher', 'references', 'rightsHolder',
#        'type',
#        ...
#        'level0Gid', 'level0Name', 'level1Gid', 'level1Name', 'level2Gid',
#        'level2Name', 'level3Gid', 'level3Name', 'iucnRedListCategory',
#        'eventType'],
#       dtype='object', length=212)

# %%
# df2 = pd.read_csv('./verbatim.txt',delimiter='\t')

# %%
# list = df2.columns

# %%
# for i in list:
    # print(i)

# %%
# df2["bed"].unique()

# %%
# df2["family"].unique()

# %%
# for i in df.columns:
    # print(i)

# %%
df.ndim
# Out:
# 2

# %%
# df2.shape

# %%
df["organismQuantityType"].unique()
# Out:
# array(['individuals'], dtype=object)

# %%
df["lifeStage"].unique()
# Out:
# array([nan])

# %%
df["taxonomicStatus"].unique()

# %%
df2["taxonomicStatus"].unique()

# %%
df.info()

# %%
df.describe()

# %%
df['islandGroup'].unique()

# %%
df.shape

# %%
df2.shape

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885595 entries, 0 to 885594
# Columns: 181 entries, gbifID to taxonRemarks
# dtypes: float64(151), int64(7), object(23)
# memory usage: 1.2+ GB

# %%
df2.describe()
# Out:
#              gbifID  accessRights  bibliographicCitation  language  license  \
# count  8.855950e+05           0.0                    0.0       0.0      0.0
# mean   2.967324e+09           NaN                    NaN       NaN      NaN
# std    8.655638e+08           NaN                    NaN       NaN      NaN
# min    2.028713e+09           NaN                    NaN       NaN      NaN
# 25%    2.028936e+09           NaN                    NaN       NaN      NaN
# 50%    3.765493e+09           NaN                    NaN       NaN      NaN
# 75%    3.765717e+09           NaN                    NaN       NaN      NaN
# max    3.765939e+09           NaN                    NaN       NaN      NaN
#
#        publisher  references  institutionID  collectionID  datasetID  ...  \
# count        0.0         0.0            0.0           0.0   885595.0  ...
# mean         NaN         NaN            NaN           NaN    74052.0  ...
# ...

# %%
list_column = df2.columns

# %%
for columns in list_column:
    if df2[columns].isna().sum() > 400000:
        del df2[columns]

# %%
list_new_cols = df2.columns

# %%
for i in lilst_new_cols:
    print(i)
# Out:
# gbifID
# modified
# rightsHolder
# type
# datasetID
# datasetName
# basisOfRecord
# occurrenceID
# individualCount
# organismQuantity
# organismQuantityType
# occurrenceStatus
# organismID
# eventID
# eventDate
# country
# decimalLatitude
# decimalLongitude
# geodeticDatum
# identificationID
# taxonID
# scientificName
# kingdom
# phylum
# class
# order
# family
# genus
# taxonRank

# %%
df2["eventDate"]
# Out:
# 0         2007-08-07T06:00Z
# 1         2017-06-19T10:24Z
# 2         2007-08-22T12:00Z
# 3         2017-06-19T16:24Z
# 4         2007-08-26T06:00Z
#                 ...
# 885590    2017-06-18T02:25Z
# 885591    2017-06-18T08:24Z
# 885592    2017-06-18T17:24Z
# 885593    2017-06-18T23:25Z
# 885594    2017-06-19T04:24Z
# Name: eventDate, Length: 885595, dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885595 entries, 0 to 885594
# Data columns (total 29 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   gbifID                885595 non-null  int64
#  1   modified              885595 non-null  object
#  2   rightsHolder          885595 non-null  object
#  3   type                  885595 non-null  object
#  4   datasetID             885595 non-null  int64
#  5   datasetName           885595 non-null  object
#  6   basisOfRecord         885595 non-null  object
#  7   occurrenceID          885595 non-null  int64
#  8   individualCount       885595 non-null  int64
#  9   organismQuantity      885595 non-null  int64
#  10  organismQuantityType  885595 non-null  object
#  11  occurrenceStatus      885595 non-null  object
#  12  organismID            885595 non-null  object
#  13  eventID               885595 non-null  object
# ...

# %%
df2["eventDate"].min()
# Out:
# '2006-07-27T06:00Z'

# %%
df2["eventDate"].max()
# Out:
# '2022-04-27T14:28Z'

# %%
df2.head()
# Out:
#        gbifID                          modified      rightsHolder   type  \
# 0  2028713273  2021-12-16 07:55:35.644328+00:00  Kristjan Adojaan  Event
# 1  2028931999  2021-12-16 11:16:00.550446+00:00  Kristjan Adojaan  Event
# 2  2028715905  2021-12-16 07:55:38.979779+00:00  Kristjan Adojaan  Event
# 3  2028936907  2021-12-16 11:16:01.008779+00:00  Kristjan Adojaan  Event
# 4  2028715906  2021-12-16 07:55:43.571024+00:00  Kristjan Adojaan  Event
#
#    datasetID   datasetName       basisOfRecord  occurrenceID  individualCount  \
# 0      74052  Birdmap data  MachineObservation       3123967                1
# 1      74052  Birdmap data  MachineObservation       3338562                1
# 2      74052  Birdmap data  MachineObservation       3123985                1
# 3      74052  Birdmap data  MachineObservation       3338580                1
# 4      74052  Birdmap data  MachineObservation       3124010                1
#
# ...

# %%
df2["individualCount"].unique()
# Out:
# array([1])

# %%
df_3 = df2.copy()

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885595 entries, 0 to 885594
# Columns: 181 entries, gbifID to taxonRemarks
# dtypes: float64(151), int64(7), object(23)
# memory usage: 1.2+ GB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885595 entries, 0 to 885594
# Columns: 181 entries, gbifID to taxonRemarks
# dtypes: float64(151), int64(7), object(23)
# memory usage: 1.2+ GB

# %%
for column in df_3.columns:
    if df_3[column].nunique() == 1:
        print(column)
        del df_3[column]
# Out:
# rightsHolder
# type
# datasetID
# datasetName
# basisOfRecord
# individualCount
# organismQuantity
# organismQuantityType
# occurrenceStatus
# locality
# geodeticDatum
# kingdom
# phylum
# class
# taxonRank

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885595 entries, 0 to 885594
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   gbifID            885595 non-null  int64
#  1   modified          885595 non-null  object
#  2   occurrenceID      885595 non-null  int64
#  3   organismID        885595 non-null  object
#  4   eventID           885595 non-null  object
#  5   eventDate         885595 non-null  object
#  6   country           885595 non-null  object
#  7   decimalLatitude   885595 non-null  object
#  8   decimalLongitude  885595 non-null  object
#  9   identificationID  885595 non-null  int64
#  10  taxonID           885595 non-null  int64
#  11  scientificName    885595 non-null  object
#  12  order             885595 non-null  object
#  13  family            885595 non-null  object
#  14  genus             885595 non-null  object
# dtypes: int64(4), object(11)
# ...

# %%
df_3.head()
# Out:
#        gbifID                          modified  occurrenceID organismID  \
# 0  2028713273  2021-12-16 07:55:35.644328+00:00       3123967    2.Maria
# 1  2028931999  2021-12-16 11:16:00.550446+00:00       3338562  111.Ahja5
# 2  2028715905  2021-12-16 07:55:38.979779+00:00       3123985    2.Maria
# 3  2028936907  2021-12-16 11:16:01.008779+00:00       3338580  111.Ahja5
# 4  2028715906  2021-12-16 07:55:43.571024+00:00       3124010    2.Maria
#
#                                      eventID          eventDate  country  \
# 0  https://plutof.ut.ee/#/event/view/3537494  2007-08-07T06:00Z  Belarus
# 1  https://plutof.ut.ee/#/event/view/3752159  2017-06-19T10:24Z  Ukraine
# 2  https://plutof.ut.ee/#/event/view/3537512  2007-08-22T12:00Z  Romania
# 3  https://plutof.ut.ee/#/event/view/3752177  2017-06-19T16:24Z  Ukraine
# 4  https://plutof.ut.ee/#/event/view/3537537  2007-08-26T06:00Z    Libya
#
#   decimalLatitude decimalLongitude  identificationID  taxonID  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885595 entries, 0 to 885594
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   gbifID            885595 non-null  int64
#  1   modified          885595 non-null  object
#  2   occurrenceID      885595 non-null  int64
#  3   organismID        885595 non-null  object
#  4   eventID           885595 non-null  object
#  5   eventDate         885595 non-null  object
#  6   country           885595 non-null  object
#  7   decimalLatitude   885595 non-null  object
#  8   decimalLongitude  885595 non-null  object
#  9   identificationID  885595 non-null  int64
#  10  taxonID           885595 non-null  int64
#  11  scientificName    885595 non-null  object
#  12  order             885595 non-null  object
#  13  family            885595 non-null  object
#  14  genus             885595 non-null  object
# dtypes: int64(4), object(11)
# ...

# %%
df2["type"].unique()
# Out:
# array(['Event'], dtype=object)

# %%
df2["locality"].unique()
# Out:
# array([nan, 'RESTRICTED'], dtype=object)

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885595 entries, 0 to 885594
# Columns: 166 entries, gbifID to taxonRemarks
# dtypes: float64(151), int64(4), object(11)
# memory usage: 1.1+ GB

# %%
for column in df_3.columns:
    if df_3[column].isna().sum() > 700000:
        print(column)
        del df_3[column]
# Out:
# accessRights
# bibliographicCitation
# language
# license
# publisher
# references
# institutionID
# collectionID
# institutionCode
# collectionCode
# ownerInstitutionCode
# informationWithheld
# dataGeneralizations
# dynamicProperties
# catalogNumber
# recordNumber
# recordedBy
# recordedByID
# sex
# lifeStage
# reproductiveCondition
# behavior
# establishmentMeans
# degreeOfEstablishment
# pathway
# georeferenceVerificationStatus
# preparations
# disposition
# associatedMedia
# associatedOccurrences
# associatedReferences
# associatedSequences
# associatedTaxa
# otherCatalogNumbers
# occurrenceRemarks
# organismName
# organismScope
# associatedOrganisms
# previousIdentifications
# organismRemarks
# materialSampleID
# parentEventID
# fieldNumber
# eventTime
# startDayOfYear
# endDayOfYear
# year
# month
# day
# verbatimEventDate
# habitat
# samplingProtocol
# sampleSizeValue
# sampleSizeUnit
# samplingEffort
# fieldNotes
# eventRemarks
# locationID
# higherGeographyID
# ...

# %%
for i in df_3.columns:
    print(f"NA values in {i} is {df_3[i].isna().sum()}")
# Out:
# NA values in gbifID is 0
# NA values in modified is 0
# NA values in occurrenceID is 0
# NA values in organismID is 0
# NA values in eventID is 0
# NA values in eventDate is 0
# NA values in country is 0
# NA values in decimalLatitude is 0
# NA values in decimalLongitude is 0
# NA values in identificationID is 0
# NA values in taxonID is 0
# NA values in scientificName is 0
# NA values in order is 0
# NA values in family is 0
# NA values in genus is 0

# %%
df_3.corr(numeric_only=True)
# Out:
#                     gbifID  occurrenceID  identificationID   taxonID
# gbifID            1.000000      0.990071          0.999735  0.130959
# occurrenceID      0.990071      1.000000          0.993043  0.139924
# identificationID  0.999735      0.993043          1.000000  0.132609
# taxonID           0.130959      0.139924          0.132609  1.000000

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885595 entries, 0 to 885594
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   gbifID            885595 non-null  int64
#  1   modified          885595 non-null  object
#  2   occurrenceID      885595 non-null  int64
#  3   organismID        885595 non-null  object
#  4   eventID           885595 non-null  object
#  5   eventDate         885595 non-null  object
#  6   country           885595 non-null  object
#  7   decimalLatitude   885595 non-null  object
#  8   decimalLongitude  885595 non-null  object
#  9   identificationID  885595 non-null  int64
#  10  taxonID           885595 non-null  int64
#  11  scientificName    885595 non-null  object
#  12  order             885595 non-null  object
#  13  family            885595 non-null  object
#  14  genus             885595 non-null  object
# dtypes: int64(4), object(11)
# ...

# %%
df_3["genus"].unique()
# Out:
# array(['Pandion', 'Grus', 'Ciconia', 'Haliaeetus', 'Clanga', 'Buteo',
#        'Botaurus', 'Aegypius'], dtype=object)

# %%
df_3["scientificName"].nunique()
# Out:
# 10

# %%
df_3["        "]
