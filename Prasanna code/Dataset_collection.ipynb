# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import csv

path = "/home/sunbeam/Desktop/Project/"

# %%
file = open(path + "trial_data.xlsx",  encoding="UTF-8")

# %%
df = pd.read_csv('/home/sunbeam/Desktop/DATASET/0031102-231002084531237/occurrence.txt', delimiter="\t")
# Out:
# /tmp/ipykernel_4427/3782199460.py:1: DtypeWarning: Columns (82,199) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/home/sunbeam/Desktop/DATASET/0031102-231002084531237/occurrence.txt', delimiter="\t")

# %%
df.head(100)
# Out:
#         gbifID  accessRights  bibliographicCitation  language       license  \
# 0   2028713273           NaN                    NaN       NaN  CC_BY_NC_4_0
# 1   2028931999           NaN                    NaN       NaN  CC_BY_NC_4_0
# 2   2028715905           NaN                    NaN       NaN  CC_BY_NC_4_0
# 3   2028936907           NaN                    NaN       NaN  CC_BY_NC_4_0
# 4   2028715906           NaN                    NaN       NaN  CC_BY_NC_4_0
# ..         ...           ...                    ...       ...           ...
# 95  2028924500           NaN                    NaN       NaN  CC_BY_NC_4_0
# 96  2028716119           NaN                    NaN       NaN  CC_BY_NC_4_0
# 97  2028930756           NaN                    NaN       NaN  CC_BY_NC_4_0
# 98  2028714474           NaN                    NaN       NaN  CC_BY_NC_4_0
# 99  2028932841           NaN                    NaN       NaN  CC_BY_NC_4_0
#
# ...

# %%
df.nunique()
# Out:
# gbifID                   885595
# accessRights                  0
# bibliographicCitation         0
# language                      0
# license                       1
#                           ...
# level2Name                 6809
# level3Gid                  8724
# level3Name                 7642
# iucnRedListCategory           3
# eventType                     0
# Length: 212, dtype: int64

# %%
df['level3Gid'].unique()
# Out:
# array([nan, 'TCD.5.1.1_1', 'TCD.17.3.5_1', ..., 'EST.12.15.7_1',
#        'LBN.5.5.5_1', 'LBN.1.1.159_1'], dtype=object)

# %%
df = pd.read_csv("/home/sunbeam/Desktop/DATASET/0031102-231002084531237/verbatim.txt",delimiter='\t')
# Out:
# /tmp/ipykernel_5242/1632631980.py:1: DtypeWarning: Columns (84,97,98) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/home/sunbeam/Desktop/DATASET/0031102-231002084531237/verbatim.txt",delimiter='\t')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885595 entries, 0 to 885594
# Columns: 181 entries, gbifID to taxonRemarks
# dtypes: float64(151), int64(7), object(23)
# memory usage: 1.2+ GB

# %%
df2 = df[:][:2000]

# %%
df2.to_csv("trial_data.xlsx")

# %%
cols =df.columns

print ("-"*59)
for i  in range(len(cols)):
    
    print(f"|{i:^5} |{cols[i]:^50}|")
# Out:
# -----------------------------------------------------------
# |  0   |                      gbifID                      |
# |  1   |                   accessRights                   |
# |  2   |              bibliographicCitation               |
# |  3   |                     language                     |
# |  4   |                     license                      |
# |  5   |                     modified                     |
# |  6   |                    publisher                     |
# |  7   |                    references                    |
# |  8   |                   rightsHolder                   |
# |  9   |                       type                       |
# | 10   |                  institutionID                   |
# | 11   |                   collectionID                   |
# | 12   |                    datasetID                     |
# | 13   |                 institutionCode                  |
# | 14   |                  collectionCode                  |
# ...

# %%
for i in df.columns:
    if type(df[i][1]) not in [bool,int,str,float]:
        df[i] = df[i].
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4962/591318582.py in <module>
#       1 for i in df.columns:
#       2     if type(df[i][1]) not in [bool,int,str,float]:
# ----> 3         df[i] = df[i].decode('UTF-8')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6200         ):
#    6201             return self[name]
# -> 6202         return object.__getattribute__(self, name)
#    6203
#    6204     @final
#
# AttributeError: 'Series' object has no attribute 'decode'

# %%
col = df.columns
for col in types[types=='unicode'].index:
    df[col] = df[col].astype(str)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4962/3360645626.py in <module>
#       1 col = df.columns
# ----> 2 for col in types[types=='unicode'].index:
#       3     df[col] = df[col].astype(str)
#
# NameError: name 'types' is not defined

# %%
df["waterBody"].isnull().count()
# Out:
# 885595
