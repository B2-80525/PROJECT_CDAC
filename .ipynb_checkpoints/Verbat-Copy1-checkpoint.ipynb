# %%
import pandas as pd

# %%
df_verbat = pd.read_csv("verbatim.txt",delimiter = '\t')
pd.set_option('display.max_columns', 300)
# Out:
# /tmp/ipykernel_16429/1802560840.py:1: DtypeWarning: Columns (84,97,98) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_verbat = pd.read_csv("verbatim.txt",delimiter = '\t')

# %%
df_verbat.head()
# Out:
#        gbifID  accessRights  bibliographicCitation  language  license  \
# 0  2028713273           NaN                    NaN       NaN      NaN
# 1  2028931999           NaN                    NaN       NaN      NaN
# 2  2028715905           NaN                    NaN       NaN      NaN
# 3  2028936907           NaN                    NaN       NaN      NaN
# 4  2028715906           NaN                    NaN       NaN      NaN
#
#                            modified  publisher  references      rightsHolder  \
# 0  2021-12-16 07:55:35.644328+00:00        NaN         NaN  Kristjan Adojaan
# 1  2021-12-16 11:16:00.550446+00:00        NaN         NaN  Kristjan Adojaan
# 2  2021-12-16 07:55:38.979779+00:00        NaN         NaN  Kristjan Adojaan
# 3  2021-12-16 11:16:01.008779+00:00        NaN         NaN  Kristjan Adojaan
# 4  2021-12-16 07:55:43.571024+00:00        NaN         NaN  Kristjan Adojaan
#
#     type  institutionID  collectionID  datasetID  institutionCode  \
# ...
